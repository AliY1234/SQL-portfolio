# %%
import pandas as pd

# Load the data
adultdata = pd.read_csv("Desktop/DataAnalysis/data/adult.data.csv")


# Display the entire DataFrame
adultdata.head(100)
# Out:
#     age         workclass  fnlwgt     education  education-num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# ..  ...               ...     ...           ...            ...
# 95   29         Local-gov  115585  Some-college             10
# 96   48  Self-emp-not-inc  191277     Doctorate             16
# 97   37           Private  202683  Some-college             10
# 98   48           Private  171095    Assoc-acdm             12
# 99   32       Federal-gov  249409       HS-grad              9
#
#         marital-status         occupation   relationship   race     sex  \
# 0        Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
# How many people of each race are represented in this dataset? 
race_count= adultdata['race'].value_counts()

# %%
race_count
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
 # Average age of men?
mean_age_male = round(adultdata.loc[adultdata['sex'] == 'Male', 'age'].mean())

# %%
mean_age_male
# Out:
# 39

# %%
# Percentage of people who have a Bachelor's degree?
bachelors_count = (adultdata['education'] == 'Bachelors').sum()

# Calculate the percentage
percentage_bachelors = round((bachelors_count / len(adultdata)) * 100)

# %%
percentage_bachelors
# Out:
# 16

# %% [raw]
# # Filtering the dataset based on education levels
# h_education = adultdata[adultdata["education"].isin(['Bachelors', 'Masters', 'Doctorate'])]
#
# l_education = adultdata[adultdata["education"].isin(["HS-grad", "11th", "9th", "Some-college", "Assoc-acdm",
#                                                      "Assoc-voc", "7th-8th", "Prof-school", "5th-6th",
#                                                      "10th", "1st-4th", "Preschool", "12th"])]
#
#
# # Calculating the percentage of people with higher education earning >50K
# higher_education_rich = round(100 * h_education[h_education['salary'] == ">50K"].shape[0] / h_education.shape[0], 1)
#
# # Calculating the percentage of people with lower education earning >50K
# lower_education_rich = round(100 * l_education[l_education['salary'] == ">50K"].shape[0] / l_education.shape[0], 1)

# %%
lower_education_rich
# Out:
# 17.4

# %%
# Minimum hours worked per week?
    
min_hours = adultdata["hours-per-week"].min()

# %%
min_hours
# Out:
# 1

# %%
# Find the number of people who work the minimum number of hours per week
num_min_workers = adultdata.loc[adultdata['hours-per-week'] == min_work_hours]

# Calculate the percentage of these people who earn >50K
Over_50k= round(100 * num_min_workers[num_min_workers['salary'] == ">50K"].shape[0] / num_min_workers.shape[0], 1)


# What country has the highest percentage of people that earn >50K?

# groups people earning <50k by countries e.g. England 15 (meaning 15 people earn more than 50k)
K_count = adultdata[adultdata['salary'] == ">50K"].groupby('native-country')['salary'].count()

# Count the Total Number of People by Country(as we need to work out percentage of high earners in the country compared to normal earners then display the highest country)
total_count = adultdata.groupby('native-country')['salary'].count()

# Calculate the Percentage of People Earning More Than $50K in descending order
K_percentage = (K_count / total_count * 100).sort_values(ascending=False)


Top_country= K_percentage.head(1)

# %%
rich_percentage
# Out:
# 10.0

# %%
Top_country
# Out:
# native-country
# Iran    41.860465
# Name: salary, dtype: float64

# %%
# what is the most popular occupation for those who earn >50K in India.
filtered_data = (adultdata[(adultdata["salary"] == ">50K")& (adultdata["native-country"] == 'India')])
                 
# Group by occupation and count occurrences
occupation_count = filtered_data.groupby('occupation')['occupation'].count().sort_values(ascending=False)
                 
Top_occupation = occupation_count.index[0]

# %%
Top_occupation
# Out:
# 'Prof-specialty'
